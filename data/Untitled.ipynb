# %%
import pandas as pd
import numpy as np
from random import randint
# Out:
# /usr/lib/python3.6/importlib/_bootstrap.py:205: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
df.tree_adress = ["м. Кропивницький " + str(a) for a in df.tree_adress]

# %%
result = pd.merge(to_merge, df, on='tree_adress', how='left')

# %%
result.name_who_ordered = ['unknown' if pd.isnull(a) else a for a in result.name_who_ordered]

# %%
result.to_csv('cleaned_tree_3.csv', index=False)

# %%
result
# Out:
#                 act_number                                        tree_adress  \
# 0    № 3608\n від 09.01.18          вул. Генерала Родимцева, 94 (за будинком)
# 1    № 3609\n від 09.01.18  м. Кропивницький вул. Героїв України, 12, корп...
# 2    № 3609\n від 09.01.18  м. Кропивницький вул. Героїв України, 12, корп...
# 3    № 3609\n від 09.01.18  м. Кропивницький вул. Героїв України, 12, корп...
# 4    № 3609\n від 09.01.18         м. Кропивницький вул. Пацаєва, 12, корп. 2
# 5    № 3610\n від 09.01.18  м. Кропивницький на перехресті вулиць Верхньої...
# 6    № 3611\n від 09.01.18  м. Кропивницький вул. Миколи Левитського (між ...
# 7    № 3611\n від 09.01.18  м. Кропивницький просп. Винниченка (уздовж дор...
# 8    № 3612\n від 09.01.18  м. Кропивницький вул. Михайлівська (біля облас...
# 9    № 3613\n від 09.01.18  м. Кропивницький вул. Петропавлівська (уздовж ...
# 10   № 3614\n від 09.01.18  м. Кропивницький вздовж русла річки Інгул (від...
# ...

# %%
! ls
# Out:
# branch_2.csv		  cleaned_tree_3.csv	   tree_planted_2.csv
# branch.csv		  cleaned_tree_3_less.csv  tree_planted.csv
# cleaned_tree_2.csv	  cleaned_tree_3_more.csv  Untitled.ipynb
# cleaned_tree_3_basic.csv  cleaned_tree.csv

# %%
df = pd.read_csv('cleaned_tree_2.csv')
df2 = pd.read_csv('branch_2.csv')
df3 = pd.read_csv('tree_planted_2.csv')

# %%
df.tree_characteristics.loc[df.tree_characteristics == 'клен 5'] = 'клен'
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df.tree_characteristics.unique()
# Out:
# array(['клен', 'тополя', 'вишня', 'абрикос', 'акація', 'берест',
#        'верба плакуча', 'тополя пірамідальна', 'сосна', 'горіх', 'яблуня',
#        'береза', 'слива', 'груша', 'шовковиця', 'липа', 'дуб', 'ясен',
#        'бузок', 'горобина', "в'яз", 'акація -', 'каштан', 'ясень',
#        'абрикос -', 'ялина', 'черешня', 'черемха', 'абрикос діам.',
#        'верба плакуча -', 'бузок (кущ)', 'акація,', 'верба',
#        'спірея, кущ'], dtype=object)

# %%
df.to_csv('cleaned_tree_2.csv')
#df2.to_csv('branch_2.csv')

# %%
df.was_cut = [False if row.cutting_act == 'NotYet' else True for index, row in df.iterrows()]

# %%
df.loc[~(df.cutting_act == 'NotYet')]
# Out:
#                 act_number                                        tree_adress  \
# 0    № 3608\n від 09.01.18  м. Кропивницький вул. Генерала Родимцева, 94 (...
# 1    № 3609\n від 09.01.18  м. Кропивницький вул. Героїв України, 12, корп...
# 2    № 3609\n від 09.01.18  м. Кропивницький вул. Героїв України, 12, корп...
# 3    № 3609\n від 09.01.18  м. Кропивницький вул. Героїв України, 12, корп...
# 4    № 3609\n від 09.01.18         м. Кропивницький вул. Пацаєва, 12, корп. 2
# 5    № 3610\n від 09.01.18  м. Кропивницький на перехресті вулиць Верхньої...
# 6    № 3611\n від 09.01.18  м. Кропивницький вул. Миколи Левитського (між ...
# 7    № 3611\n від 09.01.18  м. Кропивницький просп. Винниченка (уздовж дор...
# 8    № 3612\n від 09.01.18  м. Кропивницький вул. Михайлівська (біля облас...
# 9    № 3613\n від 09.01.18  м. Кропивницький вул. Петропавлівська (уздовж ...
# 15   № 3616\n від 18.01.18    м. Кропивницький вул. Юрія Краснокутського, 1-а
# ...

# %%
df.columns.values
# Out:
# array(['act_number', 'tree_adress', 'Latitude', 'Longitude',
#        'tree_cut_requester', 'tree_characteristics', 'number', 'date',
#        'cutting_act', 'was_cut', 'date_number', 'date_UTF',
#        'tree_adress_shorten'], dtype=object)

# %%
a = [d if d == "м. Кропивницький вздовж річки Інгул" else "no" for d in df.tree_adress_shorten]
a
# Out:
# ['no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
# ...

# %%
a = [['№ 3608\n від 09.01.18', 'м. Кропивницький вул. Генерала Родимцева, 94 (за будинком)', 48.4972704, 32.3071419, 'КП «ЖЕО № 2» Міської ради міста Кропивницького', 'клен діам. 15-20 см', 1, '№ 328/03-01-06 від 16.02.18', '16.02.18', True, '№ 328/03-01-06', '16.02.18', 'м. Кропивницький вул. Генерала Родимцева, 94']]
a * 2
# Out:
# [['№ 3608\n від 09.01.18',
#   'м. Кропивницький вул. Генерала Родимцева, 94 (за будинком)',
#   48.4972704,
#   32.3071419,
#   'КП «ЖЕО № 2» Міської ради міста Кропивницького',
#   'клен діам. 15-20 см',
#   1,
#   '№ 328/03-01-06 від 16.02.18',
#   '16.02.18',
#   True,
#   '№ 328/03-01-06',
#   '16.02.18',
#   'м. Кропивницький вул. Генерала Родимцева, 94'],
#  ['№ 3608\n від 09.01.18',
#   'м. Кропивницький вул. Генерала Родимцева, 94 (за будинком)',
#   48.4972704,
#   32.3071419,
#   'КП «ЖЕО № 2» Міської ради міста Кропивницького',
#   'клен діам. 15-20 см',
#   1,
#   '№ 328/03-01-06 від 16.02.18',
#   '16.02.18',
#   True,
#   '№ 328/03-01-06',
#   '16.02.18',
#   'м. Кропивницький вул. Генерала Родимцева, 94']]

# %%
for i, row in df.iterrows():
    print(row.values.tolist())
    break
# Out:
# ['№ 3608\n від 09.01.18', 'м. Кропивницький вул. Генерала Родимцева, 94 (за будинком)', 48.4972704, 32.3071419, 'КП «ЖЕО № 2» Міської ради міста Кропивницького', 'клен діам. 15-20 см', 1, '№ 328/03-01-06 від 16.02.18', '16.02.18', True, '№ 328/03-01-06', '16.02.18', 'м. Кропивницький вул. Генерала Родимцева, 94']

# %%
multiple_rows = []
for i, row in df2.iterrows():
    multiple_rows.append(pd.DataFrame([row.values.tolist()] * row.number,
                                      columns=row.index.values))
multiple_rows = pd.concat(multiple_rows)

# %%
multiple_rows.reset_index(drop=True)
# Out:
#                     order_number  \
# 0    № 311/03-01-06 від 14.02.18
# 1           № 590-П від 15.02.18
# 2           № 590-П від 15.02.18
# 3           № 665-М від 16.02.18
# 4    № 416/03-01-06 від 27.02.18
# 5    № 416/03-01-06 від 27.02.18
# 6    № 416/03-01-06 від 27.02.18
# 7    № 673/03-01-06 від 05.03.18
# 8          № 44-вих від 07.03.18
# 9          № 44-вих від 07.03.18
# 10         № 44-вих від 07.03.18
# 11         № 44-вих від 07.03.18
# 12         № 44-вих від 07.03.18
# 13         № 44-вих від 07.03.18
# 14         № 44-вих від 07.03.18
# 15         № 44-вих від 07.03.18
# 16         № 44-вих від 07.03.18
# 17         № 44-вих від 07.03.18
# 18         № 44-вих від 07.03.18
# 19         № 44-вих від 07.03.18
# 20         № 44-вих від 07.03.18
# 21         № 44-вих від 07.03.18
# 22         № 44-вих від 07.03.18
# 23         № 44-вих від 07.03.18
# 24         № 44-вих від 07.03.18
# 25         № 44-вих від 07.03.18
# 26         № 44-вих від 07.03.18
# ...

# %%
multiple_rows['Latitude'] = multiple_rows.Latitude.astype(float) + (
    np.random.uniform(0.0001, 0.0002, size=len(multiple_rows)) * np.random.choice([1, -1], size=len(multiple_rows)))

multiple_rows['Longitude'] = multiple_rows.Longitude.astype(float) + (
    np.random.uniform(0.0001, 0.0002, size=len(multiple_rows)) * np.random.choice([1, -1], size=len(multiple_rows)))

# %%
#len(multiple_rows.Latitude.unique())
len(multiple_rows)
# Out:
# 413

# %%
multiple_rows.number = [1 for n in multiple_rows.number]

# %%
multiple_rows.Latitude = [str(d)[:-4]+ str(randint(100, 9999)) for d in multiple_rows.Latitude]
multiple_rows.Longitude = [str(d)[:-4]+ str(randint(100, 9999)) for d in multiple_rows.Longitude]

# %%
#Це спосіб заповнити пусті клітинки замість колишніх об'єднаних
sample = df['tree_cut_requester']

temp_list = []
temp = 0
for s in sample:
    if type(s) == str: 
        temp = s
        temp_list.append(s)
    else:
        s = temp
        temp_list.append(s)
        
temp_list
# Out:
# ['КП «ЖЕО № 2» Міської ради міста Кропивницького',
#  'КП «ЖЕО № 4» Міської ради міста Кропивницького',
#  'КП «ЖЕО № 4» Міської ради міста Кропивницького',
#  'КП «ЖЕО № 4» Міської ради міста Кропивницького',
#  'КП «ЖЕО № 4» Міської ради міста Кропивницького',
#  'КП «Благоустрій» Міської ради міста Кропивницького»',
#  'КП «Благоустрій» Міської ради міста Кропивницького»',
#  'КП «Благоустрій» Міської ради міста Кропивницького»',
#  'КП «Благоустрій» Міської ради міста Кропивницького»',
#  'гр. Сирота О.М.',
#  'ГУ ЖКГ Міської ради міста Кропивницького',
#  'ГУ ЖКГ Міської ради міста Кропивницького',
#  'ГУ ЖКГ Міської ради міста Кропивницького',
#  'ГУ ЖКГ Міської ради міста Кропивницького',
#  'ПП «Босфор-Люкс»',
#  'КП «ЖЕО № 1» Міської ради міста Кропивницького',
#  'КП «ЖЕО № 1» Міської ради міста Кропивницького',
#  'КП «ЖЕО № 1» Міської ради міста Кропивницького',
#  'КП «ЖЕО № 1» Міської ради міста Кропивницького',
#  'КП «ЖЕО № 1» Міської ради міста Кропивницького',
# ...

# %%
df['tree_cut_requester'] = temp_list

# %%
df.tail()
# Out:
#                 act_number                                        tree_adress  \
# 359  № 3735\n від 31.05.18  м. Кропивницький вул. Архітектора Паученка, 51...
# 360  № 3735\n від 31.05.18  м. Кропивницький вул. Велика Перспективна, 25/...
# 361  № 3735\n від 31.05.18  м. Кропивницький вул. Архангельська, 65/108, у...
# 362  № 3735\n від 31.05.18            м. Кропивницький вул. Пашутінська, 51-а
# 363  № 3736\n від 31.05.18                  м. Кропивницький вул. Гагаріна, 7
#
#       Latitude  Longitude                              tree_cut_requester  \
# 359  48.509305  32.271507  КП «ЖЕО № 2» Міської ради міста Кропивницького
# 360  48.511587  32.268388  КП «ЖЕО № 2» Міської ради міста Кропивницького
# 361  48.505047  32.272234  КП «ЖЕО № 2» Міської ради міста Кропивницького
# 362  48.508331  32.268330  КП «ЖЕО № 2» Міської ради міста Кропивницького
# 363  48.513898  32.269310  КП «ЖЕО № 2» Міської ради міста Кропивницького
#
# ...

# %%
df['was_cut'] = [True if d == str else False for d in df['cutting_act']]
#df['was_cut'] = [1 if d == True else 0 for d in df['was_cut']]

# %%
df['was_cut'].unique()
# Out:
# array([ True])

# %%
df.head()
# Out:
#               act_number                                        tree_adress  \
# 0  № 3608\n від 09.01.18  м. Кропивницький вул. Генерала Родимцева, 94 (...
# 1  № 3609\n від 09.01.18  м. Кропивницький вул. Героїв України, 12, корп...
# 2  № 3609\n від 09.01.18  м. Кропивницький вул. Героїв України, 12, корп...
# 3  № 3609\n від 09.01.18  м. Кропивницький вул. Героїв України, 12, корп...
# 4  № 3609\n від 09.01.18         м. Кропивницький вул. Пацаєва, 12, корп. 2
#
#     Latitude  Longitude                              tree_cut_requester  \
# 0  48.497270  32.307142  КП «ЖЕО № 2» Міської ради міста Кропивницького
# 1  48.494138  32.218763  КП «ЖЕО № 4» Міської ради міста Кропивницького
# 2  48.494176  32.218718  КП «ЖЕО № 4» Міської ради міста Кропивницького
# 3  48.494195  32.218733  КП «ЖЕО № 4» Міської ради міста Кропивницького
# 4  48.495518  32.217800  КП «ЖЕО № 4» Міської ради міста Кропивницького
#
# ...

# %%
df['date_act_published'] = [d.split(" від ")[1][3:].str for d in df.act_number]

# %%
df.head()
# Out:
#               act_number                                       tree_andress  \
# 0  № 3608\n від 09.01.18  м. Кропивницький вул. Генерала Родимцева, 94 (...
# 1  № 3609\n від 09.01.18  м. Кропивницький вул. Героїв України, 12, корп...
# 2  № 3609\n від 09.01.18  м. Кропивницький вул. Героїв України, 12, корп...
# 3  № 3609\n від 09.01.18  м. Кропивницький вул. Героїв України, 12, корп...
# 4  № 3609\n від 09.01.18         м. Кропивницький вул. Пацаєва, 12, корп. 2
#
#     Latitude  Longitude                              tree_cut_requester  \
# 0  48.497258  32.307179  КП «ЖЕО № 2» Міської ради міста Кропивницького
# 1  48.494194  32.218792  КП «ЖЕО № 4» Міської ради міста Кропивницького
# 2  48.494194  32.218792  КП «ЖЕО № 4» Міської ради міста Кропивницького
# 3  48.494194  32.218792  КП «ЖЕО № 4» Міської ради міста Кропивницького
# 4  48.495596  32.217530  КП «ЖЕО № 4» Міської ради міста Кропивницького
#
# ...

# %%
df.groupby(['date_act_published'], as_index=False)['Longitude', 'Latitude'].nunique()
# Out:
#    Longitude  Latitude
# 0         21        21
# 1         17        17
# 2         15        15
# 3         56        56
# 4         39        39

# %%
df['date_number'] = [d.split(' від ')[0] if type(d) == str else [d,d][0] for d in df['date']]
df['date_UTF'] = [d.split(' від ')[1] if type(d) == str else [d,d][1] for d in df['date']]

# %%
df['tree_andress'] = ['м. Кропивницький '+d for d in df['tree_andress']]

# %%
df.cutting_act = df.date_UTF
df.head()
# Out:
#               act_number                                        tree_adress  \
# 0  № 3608\n від 09.01.18  м. Кропивницький вул. Генерала Родимцева, 94 (...
# 1  № 3609\n від 09.01.18  м. Кропивницький вул. Героїв України, 12, корп...
# 2  № 3609\n від 09.01.18  м. Кропивницький вул. Героїв України, 12, корп...
# 3  № 3609\n від 09.01.18  м. Кропивницький вул. Героїв України, 12, корп...
# 4  № 3609\n від 09.01.18         м. Кропивницький вул. Пацаєва, 12, корп. 2
#
#     Latitude  Longitude                              tree_cut_requester  \
# 0  48.497258  32.307179  КП «ЖЕО № 2» Міської ради міста Кропивницького
# 1  48.494194  32.218792  КП «ЖЕО № 4» Міської ради міста Кропивницького
# 2  48.494194  32.218792  КП «ЖЕО № 4» Міської ради міста Кропивницького
# 3  48.494194  32.218792  КП «ЖЕО № 4» Міської ради міста Кропивницького
# 4  48.495596  32.217530  КП «ЖЕО № 4» Міської ради міста Кропивницького
#
# ...

# %%
df.to_csv('cleaned_tree.csv', index=False)

# %%
df = pd.read_csv('cleaned_tree.csv')

# %%
for d in df['tree_andress']
# Out:
#                 act_number                                       tree_andress  \
# 0    № 3608\n від 09.01.18  м. Кропивницький вул. Генерала Родимцева, 94 (...
# 1    № 3609\n від 09.01.18  м. Кропивницький вул. Героїв України, 12, корп...
# 2    № 3609\n від 09.01.18  м. Кропивницький вул. Героїв України, 12, корп...
# 3    № 3609\n від 09.01.18  м. Кропивницький вул. Героїв України, 12, корп...
# 4    № 3609\n від 09.01.18         м. Кропивницький вул. Пацаєва, 12, корп. 2
# 5    № 3610\n від 09.01.18  м. Кропивницький на перехресті вулиць Верхньої...
# 6    № 3611\n від 09.01.18  м. Кропивницький вул. Миколи Левитського (між ...
# 7    № 3611\n від 09.01.18  м. Кропивницький просп. Винниченка (уздовж дор...
# 8    № 3612\n від 09.01.18  м. Кропивницький вул. Михайлівська (біля облас...
# 9    № 3613\n від 09.01.18  м. Кропивницький вул. Петропавлівська (уздовж ...
# 10   № 3614\n від 09.01.18  м. Кропивницький вздовж русла річки Інгул (від...
# ...

# %%
def functionname(x):
    import random
    import string
    rand_str = lambda n: ''.join([random.choice(string.ascii_lowercase) for i in range(n)])
    s = rand_str(10)  
    return s

# %%
df =  pd.read_csv("cleaned_tree.csv")

# %%
df['tree_andress_shorten'] = [d.split(' (')[0] for d in df['tree_andress']]

# %%
df1.to_csv("branch.csv", index=False)
df2.to_csv("tree_planted.csv", index=False)

# %%
df2
# Out:
#                   tree_type  tree_count  \
# 0                  Горобина           2
# 1         Клен гостролистий           4
# 2                    Береза           4
# 3           Липа серцелиста          70
# 4           Липа серцелиста          37
# 5           Липа серцелиста          27
# 6           Липа серцелиста          30
# 7           Липа серцелиста          11
# 8                       Туя          32
# 9           Липа серцелиста           7
# 10                      Туя          10
# 11                   Береза          10
# 12               Верба біла           2
# 13  Шовковица плакуча форма           1
#
#                                           tree_adress   Latitude  Longitude  \
# 0   Кропивницький, бульвар між вул. Волкова та вул...  48.504837  32.222557
# 1   Кропивницький, бульвар між вул. Волкова та вул...  48.504837  32.222557
# 2   Кропивницький, бульвар між вул. Волкова та вул...  48.504837  32.222557
# ...

# %%
cut = pd.read_csv('cleaned_tree.csv')
branch = pd.read_csv('branch.csv')
planted = pd.read_csv('tree_planted.csv')

# %%
planted['date_UTF'] = [d.replace("/", ".") for d in planted.date_UTF]

# %%
#df1 = pd.read_csv('branch.csv')
df2 = pd.read_csv('tree_planted.csv')

# %%
df.Latitude = [str(d)[:-3]+ str(randint(10, 999)) for d in df.Latitude]
df.Longitude = [str(d)[:-3]+ str(randint(10, 999)) for d in df.Longitude]

#df1.Latitude = [str(d)[:-3]+ str(randint(10, 999)) for d in df1.Latitude]
#df1.Longitude = [str(d)[:-3]+ str(randint(10, 999)) for d in df1.Longitude]

#df2.Latitude = [str(d)[:-3]+ str(randint(10, 999)) for d in df2.Latitude]
#df2.Longitude = [str(d)[:-3]+ str(randint(10, 999)) for d in df2.Longitude]

# %%
df.to_csv("cleaned_tree_2.csv", index=False)
#df1.to_csv("branch_2.csv", index=False)
#df2.to_csv("tree_planted_2.csv", index=False)

# %%
df.was_cut
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# 20     True
# 21     True
# 22     True
# 23     True
# 24     True
# 25     True
# 26     True
# 27     True
# 28     True
# 29     True
#        ...
# 334    True
# 335    True
# 336    True
# 337    True
# 338    True
# 339    True
# 340    True
# 341    True
# 342    True
# 343    True
# 344    True
# 345    True
# 346    True
# 347    True
# 348    True
# 349    True
# 350    True
# 351    True
# 352    True
# 353    True
# 354    True
# 355    True
# 356    True
# 357    True
# 358    True
# 359    True
# 360    True
# 361    True
# 362    True
# 363    True
# Name: was_cut, Length: 364, dtype: bool
